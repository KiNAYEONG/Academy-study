# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# 가상의 데이터를 만들어 선 그래프
x = np.arange(1,6)
y = np.array([9,4,9,9,1])

# 선 그리는 방법
# plt.plot(x축, y축 데이터)
plt.plot(x,y)

plt.show()

# %%
# x축이 늘어나는 숫자 생략 가능 y축만 대입
plt.plot(y)
plt.show()

# %% [markdown]
# ![image.png](attachment:b55ffcf0-90b4-4442-84e5-bae169e0a459.png)

# %% [markdown]
# ![image.png](attachment:0576b57c-cbb9-48c5-82e9-cf8d9097850c.png)
# ![image.png](attachment:9b7e24f1-4ebe-4e0e-b54f-544db4afe4b6.png)

# %%
# 그래프 크기 조정
plt.figure(figsize=(3,2))
plt.plot(x,y, c = 'g') #c는 color의 약자

plt.show()

# %%
# 한 셀에 여러 그래프 그리기
x1 = np.arange(1,6)
y1 = np.array([2,4,1,1,5])
# plt.plot을 이어서 쓸 경우 그래프가 겹쳐서 출력
plt.plot(x,y, ls = '-', c = 'b', marker = 'D', mec = 'r', mfc='y')
plt.plot(x1,y1, ls = '--', c = 'm', marker = '+', mfc = 'c')
plt.show()

# %%
# plt.subplot(행, 열, 몇번째)
plt.subplot(2,2,1)
plt.plot(x,y, ls = '-', c = 'b', marker = 'D', mec = 'r', mfc='y')
plt.subplot(2,2,2)
plt.plot(x1,y1, ls = '--', c = 'm', marker = '+', mfc = 'c')
plt.show()

# %% [markdown]
# ![image.png](attachment:6d0da4dd-1804-484a-b5bf-c8777cfcb558.png)

# %%
# 차트의 이름 
# 격자눈금
plt.plot(x,y)
plt.title('Test')
plt.grid()

# %%
# legend
plt.plot(x,y, label = 'test1')
plt.plot(x1,y1, label = "test2")
plt.legend() #레전드 사용 위해선 plot label 이름 지정, 코드는 위에서 아래로 내려오기 때문에, plot 다음에 써야 실행됨.
# loc를 작성하여 legend 위치 수정 가능 plt.legend(loc=10)
# shift + tab 눌러서 loc code 확인하기

# %%
# xlim, ylim - 범위 제한
#(시작, 끝) == (1,10) 1~10
plt.plot(x,y, label = 'test1')
plt.plot(x1,y1, label = "test2")
plt.xlim(1,5)
plt.ylim(1,5)
# Out:
# (1.0, 5.0)

# %%
#한글 폰트 깨질 경우
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# xlabel, ylabel
# ("타이틀")
plt.plot(x,y, label = 'test1')
plt.plot(x1,y1, label = "test2")
plt.xlabel("X축")
plt.ylabel("Y축", rotation = 0, loc = 'bottom' )
# x , y축의 각도 수정을 희망시 rotation = 각도
plt.show()

# %%
# xticks, yticks
plt.plot(x,y, label = 'test1')
plt.plot(x1,y1, label = "test2")

# 매개변수 list, array
plt.xticks(range(1,6))
plt.show()

# %%
data = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr', index_col = "인구변동요인별")
data
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %%
display(data.columns)

data_x = data.columns
# Out:
# Index(['2020', '2030', '2040', '2050', '2060', '2070'], dtype='object')

# %%
#y축을 출생아수
data_y = data.iloc[1]

# %%
#y축을 사망자수
data_y1 = data.iloc[2]

# %%
plt.plot(data_x, data_y, marker = "*" , ms = 10, label='출생아수(천명')
plt.plot(data_x, data_y1, marker = "o" , ms = 10, label='사망자수(천명')
plt.title('국가통계 요인별 장래 인구 동향')
plt.xlabel('연도')
plt.ylabel('사람수')
plt.yticks(range(150, 750, 50))
plt.grid()
plt.legend() 
plt.show()

# %% [markdown]
# ![image.png](attachment:dc2f0267-64c1-417e-b066-85548450f670.png)

# %%
temp = pd.read_csv('data/온도데이터.csv', skiprows = range(0,6), encoding = 'euc-kr')
temp
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      \t1970-07-01  156     21.7     18.3     26.1
# 1      \t1970-07-02  156     23.8     18.5     29.4
# 2      \t1970-07-03  156     23.5     22.4     25.8
# 3      \t1970-07-04  156     23.2     20.2     27.2
# 4      \t1970-07-05  156     22.3     19.6     26.9
# ...             ...  ...      ...      ...      ...
# 19757  \t2024-08-03  156     30.6     27.3     34.8
# 19758  \t2024-08-04  156     31.0     26.9     35.8
# 19759  \t2024-08-05  156     26.9     24.0     33.1
# 19760  \t2024-08-06  156     28.6     24.0     33.3
# 19761  \t2024-08-07  156     29.7     26.3     34.3
#
# [19762 rows x 5 columns]

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19762 entries, 0 to 19761
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       19762 non-null  object
#  1   지점       19762 non-null  int64
#  2   평균기온(℃)  19762 non-null  float64
#  3   최저기온(℃)  19761 non-null  float64
#  4   최고기온(℃)  19761 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 772.1+ KB

# %%
# 결측치 확인하기
temp[temp.iloc[:,3].isna()]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 1203  \t1973-10-16  156     11.9      NaN      NaN

# %%
temp.iloc[1196]
# Out:
# 날짜         \t1973-10-09
# 지점                  156
# 평균기온(℃)            14.7
# 최저기온(℃)             8.2
# 최고기온(℃)            21.7
# Name: 1196, dtype: object

# %%
temp.iloc[1198]
# Out:
# 날짜         \t1973-10-11
# 지점                  156
# 평균기온(℃)            17.8
# 최저기온(℃)            11.8
# 최고기온(℃)            23.1
# Name: 1198, dtype: object

# %%
temp['날짜'].str[-5:]
# Out:
# 0        07-01
# 1        07-02
# 2        07-03
# 3        07-04
# 4        07-05
#          ...
# 19757    08-03
# 19758    08-04
# 19759    08-05
# 19760    08-06
# 19761    08-07
# Name: 날짜, Length: 19762, dtype: object

# %%
#마이너스 기호 사용 코드
plt.rcParams['axes.unicode_minus'] = False

# %%
# 월/일 파생변수
temp['월일'] = temp['날짜'].str[-5:]
birth_temp = temp.query('월일 == "10-25"')
plt.plot(range(1971,2025),birth_temp['평균기온(℃)'])

# %%
#연도별 내 생일의 평균 기온
temp_avg_y = temp['평균기온(℃)']
plt.plot(range(1971, 2025), temp_avg_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 #연도별 내 생일의 평균 기온
#       2 temp_avg_y = temp['평균기온(℃)']
# ----> 3 plt.plot(range(1971, 2025), temp_avg_y)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
# ...

# %%
# 생일 최고, 최저기온 비교
plt.plot(range(1971,2025),birth_temp['최저기온(℃)'],label="최저기온")
plt.plot(range(1971,2025),birth_temp['최고기온(℃)'],label="최고기온")
plt.title('birth_high_low_data')
plt.legend(loc=1) 
plt.show()

# %% [markdown]
# # 히스토그램
# - 분포도 파악을 목적으로 하는 그래프

# %%
# plt.hist()
np.random.seed(3)
test1 = np.random.randint(1,7,size =100)

np.unique(test1, return_counts = True)
# Out:
# (array([1, 2, 3, 4, 5, 6]), array([23, 15, 17, 13, 15, 17], dtype=int64))

# %%
#매개변수 데이터, bins = 구간 수
plt.hist(test1, bins = 6)
plt.show()

# %%
temp
#연도별 8월의 평균 기온
#월 파생변수 만들기

temp['월'] = temp['월일'].str[:2]
temp
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1970-07-01  156     21.7     18.3     26.1  07-01  07
# 1      \t1970-07-02  156     23.8     18.5     29.4  07-02  07
# 2      \t1970-07-03  156     23.5     22.4     25.8  07-03  07
# 3      \t1970-07-04  156     23.2     20.2     27.2  07-04  07
# 4      \t1970-07-05  156     22.3     19.6     26.9  07-05  07
# ...             ...  ...      ...      ...      ...    ...  ..
# 19757  \t2024-08-03  156     30.6     27.3     34.8  08-03  08
# 19758  \t2024-08-04  156     31.0     26.9     35.8  08-04  08
# 19759  \t2024-08-05  156     26.9     24.0     33.1  08-05  08
# 19760  \t2024-08-06  156     28.6     24.0     33.3  08-06  08
# 19761  \t2024-08-07  156     29.7     26.3     34.3  08-07  08
#
# [19762 rows x 7 columns]

# %%
temp8 = temp.query('월 == "08"')

# %%
plt.hist(temp8['평균기온(℃)'], bins = 100, color = 'r')
plt.show()

# %%
plt.hist(temp8['최저기온(℃)'], bins = 100, color = 'r', alpha = 0.5) # alpha 투명도 0~1
plt.hist(temp8['최고기온(℃)'], bins = 100, color = 'b', alpha = 0.5)
plt.show()

# %% [markdown]
# # boxplot
# 1. 상자 : 데이터의 사분위를 의미함.
# 2. 상자 내 선 : 중앙값
# 3. 상자 위/아래 수염 : 데이터의 전체 범위
# 4. 수염 위에 점 : 이상치

# %%
np.random.seed(1)
temp_data = np.random.randint(10, size = 10)
temp_data
# Out:
# array([5, 8, 9, 5, 0, 0, 1, 7, 6, 9])

# %%
#plt.boxplot()
plt.boxplot(temp_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12dfc110f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12dfc111890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12dfc0d0250>],
#  'medians': [<matplotlib.lines.Line2D at 0x12dfc112a10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12dfc1132d0>],
#  'means': []}

# %%
temp_data = np.append(temp_data, 100)
temp_data
# Out:
# array([  5,   8,   9,   5,   0,   0,   1,   7,   6,   9, 100])

# %%
#plt.boxplot()
plt.boxplot(temp_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12dfc16a710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12dfc16be90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12dfc169c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x12dfc1714d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12dfc171ed0>],
#  'means': []}

# %%
plt.boxplot(temp8['평균기온(℃)'])
plt.show()

# %%
plt.boxplot(temp8['최저기온(℃)'])
plt.boxplot(temp8['최고기온(℃)'])
plt.show()

# %%
plt.boxplot(temp8[['최저기온(℃)','최고기온(℃)']], labels = ['최저','최고'])
plt.show()

# %% [markdown]
# colorchart
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors

# %%
bar_x = np.arange(1,4)
bar_y = np.array([60,57,84])

# plt.bar(x,y)
plt.bar(bar_x,bar_y)
# Out:
# <BarContainer object of 3 artists>

# %%
import math

import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * ncols + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * ncols)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %% [markdown]
# ### fontdict
# - color
# - size
# - family : 글꼴
# - weight : 굵기

# %%
plt.bar(bar_x,bar_y,color = ['lightgreen','lavenderblush','cadetblue'])
#bar에 text 넣기
#plt.text(x데이터, y데이터, 텍스트)

# ha - horizontal alignment : center, right, left
# va - vertical alignment : top, bottom, center, baseline

for i in range(len(bar_x)) :
    plt.text(bar_x[i],bar_y[i], bar_y[i], fontdict={'color':'red',"size":20}, ha = "center", va = 'bottom')
    
#plt.text(bar_x[0],bar_y[0], bar_y[0], fontdict={'color':'red',"size":20}, ha = "center", va = 'bottom')
#plt.text(bar_x[1],bar_y[1], bar_y[1], fontdict={'color':'red',"size":20}, ha = "center", va = 'bottom')

plt.show()

# %%
economic = pd.read_csv('data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv', encoding = 'euc-kr')
economic.head(2)
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0    서울특별시  남자          4007         2849      2760        89          1158
# 1    서울특별시  여자          4440         2418      2347        72          2022
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 0        71.1    68.9     3.1
# 1        54.5     NaN     3.0

# %%
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        24 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
economic[economic['고용률(%)'].isna()].head(1)
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 1    서울특별시  여자          4440         2418      2347        72          2022
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 1        54.5     NaN     3.0

# %%
emp = economic['취업자 (천명)']/economic['15세이상인구 (천명)']*100
emp_r = round(emp,1) # 소수점 1자리 수정 코드
emp_r
# Out:
# 0     68.9
# 1     52.9
# 2     67.3
# 3     48.8
# 4     69.0
# 5     50.7
# 6     72.6
# 7     54.8
# 8     67.9
# 9     51.7
# 10    72.6
# 11    53.0
# 12    71.4
# 13    48.1
# 14    76.3
# 15    52.5
# 16    75.0
# 17    53.5
# 18    69.7
# 19    58.2
# 20    75.2
# 21    56.4
# 22    75.9
# 23    57.8
# 24    70.5
# 25    56.5
# 26    74.9
# 27    59.5
# 28    73.2
# 29    55.0
# 30    70.7
# 31    52.1
# 32    77.5
# 33    67.0
# dtype: float64

# %%
economic['고용률(%)'] = emp_r

# %%
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
# 실업률 전처리
# 실업자 / 경제활동인구
# economic['실업자 (천명)']/economic['경제활동인구 (천명)'] *100 실업률 구하기
unemp = economic['실업자 (천명)']/economic['경제활동인구 (천명)'] *100

# %%
unemp_r = round(unemp,1) # 변수에 결측지 없는 실업률 초기화
unemp_r
# Out:
# 0     3.1
# 1     3.0
# 2     2.8
# 3     3.0
# 4     2.4
# 5     2.3
# 6     2.8
# 7     2.0
# 8     2.3
# 9     2.3
# 10    1.1
# 11    2.0
# 12    3.1
# 13    2.6
# 14    1.7
# 15    1.2
# 16    2.2
# 17    2.6
# 18    2.4
# 19    2.5
# 20    2.2
# 21    0.7
# 22    1.9
# 23    1.5
# 24    1.6
# 25    1.5
# 26    1.4
# 27    1.3
# 28    2.4
# 29    2.1
# 30    2.6
# 31    2.6
# 32    2.2
# 33    1.0
# dtype: float64

# %%
economic['실업률(%)'] = unemp_r # 기존 실업률 변수에 결측치 없는 값 넣어주기

# %%
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        34 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
# 시 도별 고용률이 높은 도시
economic
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0     서울특별시  남자          4007         2849      2760        89          1158
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 2     부산광역시  남자          1406          973       946        27           433
# 3     부산광역시  여자          1528          768       745        23           760
# 4     대구광역시  남자          1001          708       691        17           294
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# ...

# %%
# 행정시도 데이터가 남성/여성 groupby 진행

# groupby 동시에 인덱스 -> 컬럼
state_emp = economic[['행정구역(시도)','고용률(%)']].groupby('행정구역(시도)',as_index = False).mean()

# %%
plt.bar(state_emp['행정구역(시도)'], state_emp['고용률(%)'])
plt.title('시도별 고용률 평균')
plt.ylim(55,80) #50 이하 데이터 자르기
plt.xticks(rotation = 90) # rotation = 각도

plt.xlabel('행정구역(시도)')
plt.ylabel('고용률(%)')
plt.show()

# %%
plt.barh(state_emp['행정구역(시도)'], state_emp['고용률(%)'])
plt.xlim(55,80)
# Out:
# (55.0, 80.0)

# %% [markdown]
# # pie chart
# 참고하기 좋은 사이트
# https://benn.tistory.com/36

# %%
import seaborn as sns

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.color_palette.html

# %%
colors = sns.color_palette("pastel")
colors
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sizes = [30,40,20,10] # 각 부분의 크기 담당 (백분율)
labels = ['a','b','c','d'] # size의 개수와 일치

# 파이 차트 size, label autopct = 소수점 '%.숫자f%%'
# startangle = 90 첫 데이터의 시작할 각도
# explode - 일정 부분을 강조 [size 개수에 맞춰 0~1 숫자]
plt.pie(sizes, labels = labels, autopct='%.1f%%', startangle = 90, explode = [0.1,0,0,0], colors = colors)
plt.show()

# %%
# 각 시도별 실업자
economic.head(2)
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0    서울특별시  남자          4007         2849      2760        89          1158
# 1    서울특별시  여자          4440         2418      2347        72          2022
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 0        71.1    68.9     3.1
# 1        54.5    52.9     3.0

# %%
# groupby
unemp_cnt = economic.groupby('행정구역(시도)', as_index = False).agg(실업자수 = ('실업자 (천명)', 'sum'))

# %%
unemp_cnt.head(2)
# Out:
#   행정구역(시도)  실업자수
# 0      강원도    21
# 1      경기도   185

# %%
plt.pie(unemp_cnt['실업자수'], labels=unemp_cnt['행정구역(시도)'], autopct = '%.1f%%')
plt.legend(loc=1, bbox_to_anchor = (1.8,1.0)) #(오른쪽 이동, 위 이동)
plt.show()
